# %%
import random

# %% [markdown]
# ## returns some integer value between a,b

# %%
random.randint(1,10)
# Out:
# 4

# %% [markdown]
# #### Return an object capturing the current internal state of the generator

# %%
random.getstate()
# Out:
# (3,
#  (300267419,
#   4001308357,
#   509765719,
#   2700529184,
#   3966168476,
#   3231905793,
#   750584623,
#   1018350286,
#   1841862567,
#   1137284826,
#   3525066494,
#   4253214535,
#   4052307782,
#   482446654,
#   2594853753,
#   2248474162,
#   34776672,
#   1337096459,
#   763236969,
#   684350809,
#   1237529225,
#   3529104300,
#   496321953,
#   2570684809,
#   1448176058,
#   2697283321,
#   2952545382,
#   2519759355,
#   1010115492,
#   1103601880,
#   1656728660,
#   2393904198,
#   2846101263,
#   4145518291,
#   469616487,
#   169863801,
#   1151943240,
#   2893985513,
#   1314628284,
#   1534047439,
#   4087449457,
#   4183884881,
#   651616628,
#   3805822254,
#   2878749494,
#   2212193919,
#   1404687615,
#   2308822985,
#   1489699505,
#   2893636734,
#   962050966,
#   352176541,
#   3907549990,
#   526899551,
#   3194978581,
#   3732000577,
#   1890141055,
#   1150914437,
#   1837150012,
#   1137212891,
#   2135611542,
#   1286686156,
#   2226791761,
# ...

# %%
myList = [4,5,6,7,8,9,10,14,15]   #e.g. it will choose randomly which player will play first

# %%
list = ['a', 'b','c','d']

# %%
random.choice(myList)
# Out:
# 15

# %%
random.choice(list)
# Out:
# 'a'

# %%
random.shuffle(list)    #e.g.  to shuffle the cards of decks

# %%
list
# Out:
# ['d', 'a', 'c', 'b']

# %% [markdown]
# ## returns random value between 0,1

# %%
random.random()
# Out:
# 0.020321302925004447

# %% [markdown]
# ### returns random float value between given range

# %%
random.uniform(1,20)
# Out:
# 11.044991908487711

# %% [markdown]
# ## Import library using an alias

# %%
import random as r

# %%
r.random()
# Out:
# 0.3602014603153798

# %%
my_list = [2,3,4, 'hello', 'HI', True, False]

# %%
r.choice(my_list)
# Out:
# 'HI'

# %%
r.shuffle(my_list)

# %%
my_list
# Out:
# [3, 2, 'HI', 'hello', 4, False, True]

# %% [markdown]
# ## Importing just selecting functions

# %%
from random import randint, uniform

# %%
randint(1,1000)
# Out:
# 586

# %%
uniform(1,50)
# Out:
# 14.475899881548946

# %%
number = random.randint(0,10)

# %%
number
# Out:
# 8
